# %% [markdown]
# # Pandas

# %% [markdown]
# > Pandas uses the anocada ewhich comes with pandas,and therefore we dont have to install it, we just import

# %%
import pandas as pd
import numpy as np

# %%
# Another option not too popular
from pandas import Series, DataFrame # note 'S', 'D' and 'F'

# %% [markdown]
# ### Pandas Data Structures
# **Series**

# %%
series_data = pd.Series([4,7,-5,3,10])
series_data
# Out:
# 0     4
# 1     7
# 2    -5
# 3     3
# 4    10
# dtype: int64

# %%
# index attribute
series_data.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Pass a label for the index
series_data = pd.Series([4,7,-5,3,10], index = ['a','b','c','d','e'],
                        name = 'series_data')

# %%
series_data
# Out:
# a     4
# b     7
# c    -5
# d     3
# e    10
# Name: series_data, dtype: int64

# %%
#index
series_data.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
# values
series_data.values
# Out:
# array([ 4,  7, -5,  3, 10], dtype=int64)

# %%
# names
series_data.name
# Out:
# 'series_data'

# %%
# dtype
series_data.dtype
# Out:
# dtype('int64')

# %%
series_data = pd.Series([4,7,-5,3,'ten'], index = ['a','b','c','d','e'],
                        name = 'series_data')
series_data
# Out:
# a      4
# b      7
# c     -5
# d      3
# e    ten
# Name: series_data, dtype: object

# %%
# dtype
series_data.dtype
# Out:
# dtype('O')

# %%
# shape
series_data.shape
# Out:
# (5,)

# %%
# size
series_data.size
# Out:
# 5

# %%
series_data.ndim
# Out:
# 1

# %%
#empty
series_data.empty
# Out:
# False

# %%
empty_series = pd.Series([])
empty_series.empty
# Out:
# True

# %%
# hasnans
series_data.hasnans
# Out:
# False

# %%
#index to see the value
series_data['d']
# Out:
# 3

# %%
series_data['d']= np.nan

# %%
series_data.hasnans
# Out:
# True

# %%
series_data
# Out:
# a      4
# b      7
# c     -5
# d    NaN
# e    ten
# Name: series_data, dtype: object

# %%
#is_unique
series_data.is_unique
# Out:
# True

# %%
series_data['b'] = 4
series_data
# Out:
# a      4
# b      4
# c     -5
# d    NaN
# e    ten
# Name: series_data, dtype: object

# %%
series_data.is_unique
# Out:
# False

# %% [markdown]
# **Series Manipulation**

# %%
# Indexing with label
series_data[['a','d','c']]
# Out:
# a      4
# d    NaN
# c     -5
# Name: series_data, dtype: object

# %%
# Slicing with labels behaves differently than normal python slicing in that the endpoint is inclusive
series_data['a':'c']
# Out:
# a     4
# b     4
# c    -5
# Name: series_data, dtype: object

# %%
# indexing with index number
series_data[3]
# Out:
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\345103614.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   series_data[3]
# nan

# %%
series_data[2:]
# Out:
# c     -5
# d    NaN
# e    ten
# Name: series_data, dtype: object

# %%
# applying numpy function or numpy like operation
series_int = pd.Series([2,9,4,3,5,8,12])
series_int
# Out:
# 0     2
# 1     9
# 2     4
# 3     3
# 4     5
# 5     8
# 6    12
# dtype: int64

# %%
series_int > 6
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
series_int[series_int > 6]
# Out:
# 1     9
# 5     8
# 6    12
# dtype: int64

# %%
# multiply a scalar
series_int *2
# Out:
# 0     4
# 1    18
# 2     8
# 3     6
# 4    10
# 5    16
# 6    24
# dtype: int64

# %%
np.exp(series_int)
# Out:
# 0         7.389056
# 1      8103.083928
# 2        54.598150
# 3        20.085537
# 4       148.413159
# 5      2980.957987
# 6    162754.791419
# dtype: float64

# %%
# apply a numpy function
np.exp(series_int)
# Out:
# 0         7.389056
# 1      8103.083928
# 2        54.598150
# 3        20.085537
# 4       148.413159
# 5      2980.957987
# 6    162754.791419
# dtype: float64

# %% [markdown]
# > Another way to think of series as a fixed-length ordered dict - a mapping of index labels to data values

# %%
'b' in series_data
# Out:
# True

# %%
'f' in series_data
# Out:
# False

# %%
# Create a series from a dictionary
sdata = {'Ohio': 30000, 'Texas': 2000,'Oregon': 900, 'Utah': 5000}
states = pd.Series(sdata)

# %%
states
# Out:
# Ohio      30000
# Texas      2000
# Oregon      900
# Utah       5000
# dtype: int64

# %%
states.index
# Out:
# Index(['Ohio', 'Texas', 'Oregon', 'Utah'], dtype='object')

# %%
#Overriding the dict keys
state_2 = pd.Series(sdata, index=['California', 'Ohio', 'Texas', 'Oregon'])

# %%
state_2
# Out:
# California        NaN
# Ohio          30000.0
# Texas          2000.0
# Oregon          900.0
# dtype: float64

# %%
# pd.isnull
pd.isnull(state_2)
# Out:
# California     True
# Ohio          False
# Texas         False
# Oregon        False
# dtype: bool

# %%
# notnull()
pd.notnull(state_2)
# Out:
# California    False
# Ohio           True
# Texas          True
# Oregon         True
# dtype: bool

# %%
# Indices are automatically aligned in arithmetical operations
series_int + series_int
# Out:
# 0     4
# 1    18
# 2     8
# 3     6
# 4    10
# 5    16
# 6    24
# dtype: int64

# %%
# index can have a name
state_2.index.name = 'State'

# %%
state_2.index.name
# Out:
# 'State'

# %%
state_2
# Out:
# State
# California        NaN
# Ohio          30000.0
# Texas          2000.0
# Oregon          900.0
# dtype: float64

# %%
series_data
# Out:
# a      4
# b      4
# c     -5
# d    NaN
# e    ten
# Name: series_data, dtype: object

# %%
# Series 's index can be altered inplace by assignmnet
series_data.index = ['Bob', 'Joe', 'Will', 'Jeff', 'Steve']
series_data
# Out:
# Bob        4
# Joe        4
# Will      -5
# Jeff     NaN
# Steve    ten
# Name: series_data, dtype: object

# %%
series_data.index.name = 'Names'
series_data
# Out:
# Names
# Bob        4
# Joe        4
# Will      -5
# Jeff     NaN
# Steve    ten
# Name: series_data, dtype: object

# %% [markdown]
# **DataFrame**

# %%
data = {'state': ['Ohio', ' Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop':[1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
       }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
df.head(2)
# Out:
#    state  year  pop
# 0   Ohio  2000  1.5
# 1   Ohio  2001  1.7

# %%
df.tail(3)
# Out:
#     state  year  pop
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
df.head(-5)
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5

# %%
pd.DataFrame(data, columns = ['year', 'state','pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
# you need to assign variable to keep DataFrame for further analysis
df = pd.DataFrame(data, columns = ['year', 'state','pop'])

# %%
df
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
df_missing = pd.DataFrame(data, columns = ['year', 'state','pop', 'debt'], index = ['one', 'two',
                                                                                   'three', 'four', 'five',
                                                                                     'six'])
df_missing
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
# check the attributes
df.columns  #columns labels
# Out:
# Index(['year', 'state', 'pop'], dtype='object')

# %%
df.index #rows labels
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df_missing.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
df.shape
# Out:
# (6, 3)

# %%
df.size
# Out:
# 18

# %%
df.ndim
# Out:
# 2

# %%
df.values # The underlying data is a 2D NumPy array
# Out:
# array([[2000, 'Ohio', 1.5],
#        [2001, ' Ohio', 1.7],
#        [2002, 'Ohio', 3.6],
#        [2001, 'Nevada', 2.4],
#        [2002, 'Nevada', 2.9],
#        [2003, 'Nevada', 3.2]], dtype=object)

# %%
df.dtypes
# Out:
# year       int64
# state     object
# pop      float64
# dtype: object

# %%
df.empty
# Out:
# False

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=6, step=1),
#  Index(['year', 'state', 'pop'], dtype='object')]

# %%
df_missing.axes
# Out:
# [Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object'),
#  Index(['year', 'state', 'pop', 'debt'], dtype='object')]

# %%
# Dataframe from nested dict of dicts
nest_dict_data = {'Nevada': {2001: 2.4, 2002: 2.9},
                  'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6
                 }}
nest_dict_data
# Out:
# {'Nevada': {2001: 2.4, 2002: 2.9}, 'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}

# %%
df_nest = pd.DataFrame(nest_dict_data)
df_nest
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5

# %%
df_nest.index.name

# %%
df_nest.index.name = 'year'
df_nest.columns.name = 'state'

# %%
df_nest
# Out:
# state  Nevada  Ohio
# year
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
df_nest.index.name, df_nest.columns.name
# Out:
# ('year', 'state')

# %%
# summary infromation about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6 non-null      int64
#  1   state   6 non-null      object
#  2   pop     6 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 276.0+ bytes

# %%
df
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
df_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, one to six
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6 non-null      int64
#  1   state   6 non-null      object
#  2   pop     6 non-null      float64
#  3   debt    0 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 240.0+ bytes

# %%
df_missing
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %% [markdown]
# ***Most useful pandas operation and functions***
#
# > Selecting and viewing data

# %%
# To retrieve column values, 2 ways. 1. dict like, 2. attribute
df['year'] #dicty like notation
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
df.state # using attribute system -will only work when columns names have no space
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object

# %%
df.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
# Assigning a column that does not exist to create a new colun in a DataFrame
df['capital city'] = ['columbia', 'columbia','columbia', 'carson city', 'carson city', 'carson city']
df
# Out:
#    year   state  pop capital city
# 0  2000    Ohio  1.5     columbia
# 1  2001    Ohio  1.7     columbia
# 2  2002    Ohio  3.6     columbia
# 3  2001  Nevada  2.4  carson city
# 4  2002  Nevada  2.9  carson city
# 5  2003  Nevada  3.2  carson city

# %%
df['Location'] = ['America', 'America', 'America', 'America', 'America', 'America']
df
# Out:
#    year   state  pop capital city Location
# 0  2000    Ohio  1.5     columbia  America
# 1  2001    Ohio  1.7     columbia  America
# 2  2002    Ohio  3.6     columbia  America
# 3  2001  Nevada  2.4  carson city  America
# 4  2002  Nevada  2.9  carson city  America
# 5  2003  Nevada  3.2  carson city  America

# %%
#df.capital city   # How we have written the word , will result to an eeror coz city wont be included in the word

# %%
df['capital city']
# Out:
# 0       columbia
# 1       columbia
# 2       columbia
# 3    carson city
# 4    carson city
# 5    carson city
# Name: capital city, dtype: object

# %% [markdown]
# *idexing, selection and filtering*

# %%
df_missing['state'] #single column
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
df_missing[['state', 'year']] # Multiple column indexing
# Out:
#         state  year
# one      Ohio  2000
# two      Ohio  2001
# three    Ohio  2002
# four   Nevada  2001
# five   Nevada  2002
# six    Nevada  2003

# %%
df_missing[:2]
# Out:
#      year  state  pop debt
# one  2000   Ohio  1.5  NaN
# two  2001   Ohio  1.7  NaN

# %%
df_missing['pop'] > 2.5
# Out:
# one      False
# two      False
# three     True
# four     False
# five      True
# six       True
# Name: pop, dtype: bool

# %%
df_missing[df_missing['pop'] > 2.5]
# Out:
#        year   state  pop debt
# three  2002    Ohio  3.6  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %% [markdown]
# # iloc(), loc()
# > They help you nto select a subset of the rows and columns from a DataFrame with NumpY LIKE rotation using
# either axis label (loc()) or axix intengers(iloc())

# %%
df_missing.head(3)
# Out:
#        year  state  pop debt
# one    2000   Ohio  1.5  NaN
# two    2001   Ohio  1.7  NaN
# three  2002   Ohio  3.6  NaN

# %%
# Select single row and all columns with labels
df_missing.loc['four']
# Out:
# year       2001
# state    Nevada
# pop         2.4
# debt        NaN
# Name: four, dtype: object

# %%
# Select single row and multiple columns with labels
df_missing.loc['four', ['year', 'pop']]
# Out:
# year    2001
# pop      2.4
# Name: four, dtype: object

# %%
#Select single row and all columns with integer
df_missing.iloc[3,:]
# Out:
# year       2001
# state    Nevada
# pop         2.4
# debt        NaN
# Name: four, dtype: object

# %%
# select single row and multiple columns with integers
df_missing.iloc[3,[0,2]]
# Out:
# year    2001
# pop      2.4
# Name: four, dtype: object

# %%
# select all rows and 1 column
df_missing.loc[:,'state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
# Selecting some rows and some columns with labels
df_missing.loc[:'four',['state', 'pop']]
# Out:
#         state  pop
# one      Ohio  1.5
# two      Ohio  1.7
# three    Ohio  3.6
# four   Nevada  2.4

# %% [markdown]
# > Contrally to usual python slicing, for label slicing. for label slicing  the stop part is inclusive

# %%
# select all rows and last columns with integer
df_missing.iloc[:, [-1]]
# Out:
#       debt
# one    NaN
# two    NaN
# three  NaN
# four   NaN
# five   NaN
# six    NaN

# %%
df_missing.iloc[:, [3]]
# Out:
#       debt
# one    NaN
# two    NaN
# three  NaN
# four   NaN
# five   NaN
# six    NaN

# %%
df_missing.iloc[:, 3:]
# Out:
#       debt
# one    NaN
# two    NaN
# three  NaN
# four   NaN
# five   NaN
# six    NaN

# %%
# some rows n
df_missing.iloc[0:4, 0:3]
# Out:
#        year   state  pop
# one    2000    Ohio  1.5
# two    2001    Ohio  1.7
# three  2002    Ohio  3.6
# four   2001  Nevada  2.4

# %%
#df_missing.iloc[0:4, 0:3][df_missing['pop'[ > 2]]]

# %% [markdown]
# **Home Practise**
#  `pd.at` and `pd.iat`

# %%
df_missing.at['one', 'state']
# Out:
# 'Ohio'

# %% [markdown]
# **Pandas I/O for External DataFrame**

# %%
# !type car_sales_clean.csv
# Out:
# Make,Colour,Odometer (KM),Doors,Price
# Toyota,White,150043,4,4000.0
# Honda,Red,87899,4,5000.0
# Toyota,Blue,32549,3,7000.0
# BMW,Black,11179,5,22000.0
# Nissan,White,213095,4,3500.0
# Toyota,Green,99213,4,4500.0
# Honda,Blue,45698,4,7500.0
# Honda,Blue,54738,4,7000.0
# Toyota,White,60000,4,6250.0
# Nissan,White,31600,4,9700.0

# %%
# import csv
pd.read_csv('car-sales.csv')
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# import 
uk_accidents = pd.read_excel('uk_accidents_pd.xlsx', nrows = 100)

# %%
uk_accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Index                    100 non-null    object
#  1   Accident_Severity        100 non-null    object
#  2   Accident Date            100 non-null    datetime64[ns]
#  3   Latitude                 100 non-null    float64
#  4   Light_Conditions         100 non-null    object
#  5   District Area            100 non-null    object
#  6   Longitude                100 non-null    float64
#  7   Number_of_Casualties     100 non-null    int64
#  8   Number_of_Vehicles       100 non-null    int64
#  9   Road_Surface_Conditions  100 non-null    object
#  10  Road_Type                98 non-null     object
#  11  Urban_or_Rural_Area      100 non-null    object
#  12  Weather_Conditions       98 non-null     object
#  13  Vehicle_Type             100 non-null    object
# ...

# %%
uk_accidents['Accident_Severity']. value_counts()
# Out:
# Accident_Severity
# Slight     74
# Serious    22
# Fatal       4
# Name: count, dtype: int64

# %%
pwd    # This check where we have the files installed
# Out:
# 'C:\\Users\\ephan'

# %%
uk_accidents = pd.read_excel('uk_accidents_pd.xlsx', nrows = 100)

# %%
uk_accidents = pd.read_excel("data/uk_accidents_pd.xlsx")

# %%
uk_accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  datetime64[ns]
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %%
uk_accidents.head()
# Out:
#            Index Accident_Severity Accident Date   Latitude  \
# 0  200701BS64157           Serious    2019-06-05  51.506187
# 1  200701BS65737           Serious    2019-07-02  51.495029
# 2  200701BS66127           Serious    2019-08-26  51.517715
# 3  200701BS66128           Serious    2019-08-16  51.495478
# 4  200701BS66837            Slight    2019-09-03  51.488576
#
#               Light_Conditions           District Area  Longitude  \
# 0        Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                     Daylight  Kensington and Chelsea  -0.173647
# 2  Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                     Daylight  Kensington and Chelsea  -0.202731
# 4        Darkness - lights lit  Kensington and Chelsea  -0.192487
#
#    Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                     1                   2                     Dry
# ...

# %%
uk_accidents.columns
# Out:
# Index(['Index', 'Accident_Severity', 'Accident Date', 'Latitude',
#        'Light_Conditions', 'District Area', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Road_Surface_Conditions',
#        'Road_Type', 'Urban_or_Rural_Area', 'Weather_Conditions',
#        'Vehicle_Type'],
#       dtype='object')

# %%
columns = ['Accident_Severity', 'Accident Date', 'Latitude',
       'Light_Conditions', 'District Area', 'Longitude',
       'Number_of_Casualties', 'Number_of_Vehicles']

# %%
uk_accidents_small = pd.read_excel("uk_accidents_pd.xlsx", nrows = 200, usecols = columns)

# %%
uk_accidents_small
# Out:
#     Accident_Severity Accident Date   Latitude             Light_Conditions  \
# 0             Serious    2019-06-05  51.506187        Darkness - lights lit
# 1             Serious    2019-07-02  51.495029                     Daylight
# 2             Serious    2019-08-26  51.517715  Darkness - lighting unknown
# 3             Serious    2019-08-16  51.495478                     Daylight
# 4              Slight    2019-09-03  51.488576        Darkness - lights lit
# ..                ...           ...        ...                          ...
# 195            Slight    2019-04-20  51.494813                     Daylight
# 196            Slight    2019-04-23  51.496577                     Daylight
# 197            Slight    2019-05-03  51.514990                     Daylight
# 198            Slight    2019-04-27  51.515247                     Daylight
# 199            Slight    2019-05-01  51.509886                     Daylight
#
# ...

# %%
# Import json
data_json = pd.read_json('sample.json')
data_json
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# Exporting dataframe _saving to csv
df_missing.to_csv("df_missing.csv")

# %%
new_df_missing = pd.read_csv('df_missing.csv')

# %%
new_df_missing
# Out:
#   Unnamed: 0  year   state  pop  debt
# 0        one  2000    Ohio  1.5   NaN
# 1        two  2001    Ohio  1.7   NaN
# 2      three  2002    Ohio  3.6   NaN
# 3       four  2001  Nevada  2.4   NaN
# 4       five  2002  Nevada  2.9   NaN
# 5        six  2003  Nevada  3.2   NaN

# %%
df_missing.to_csv('df_missing.csv', index = False)   # this way it wont add a column like above one (unnamed index 0)

# %%
new_df_missing = pd.read_csv('df_missing.csv')
new_df_missing
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   NaN
# 1  2001    Ohio  1.7   NaN
# 2  2002    Ohio  3.6   NaN
# 3  2001  Nevada  2.4   NaN
# 4  2002  Nevada  2.9   NaN
# 5  2003  Nevada  3.2   NaN

# %%
df_missing.to_csv('df_missing.csv')

# %%
new_df_missing = pd.read_csv('df_missing.csv')
new_df_missing
# Out:
#   Unnamed: 0  year   state  pop  debt
# 0        one  2000    Ohio  1.5   NaN
# 1        two  2001    Ohio  1.7   NaN
# 2      three  2002    Ohio  3.6   NaN
# 3       four  2001  Nevada  2.4   NaN
# 4       five  2002  Nevada  2.9   NaN
# 5        six  2003  Nevada  3.2   NaN

# %%
current_df_missing = pd.read_csv('df_missing.csv', index_col = 0)  #this removes the the column highlest in the code
current_df_missing
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7   NaN
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4   NaN
# five   2002  Nevada  2.9   NaN
# six    2003  Nevada  3.2   NaN

# %%
current_df_missing = pd.read_csv('df_missing.csv', index_col = 2) #python takes the index 2 and make it the first elemnt
current_df_missing
# Out:
#        Unnamed: 0  year  pop  debt
# state
# Ohio          one  2000  1.5   NaN
#  Ohio         two  2001  1.7   NaN
# Ohio        three  2002  3.6   NaN
# Nevada       four  2001  2.4   NaN
# Nevada       five  2002  2.9   NaN
# Nevada        six  2003  3.2   NaN

# %%
current_df_missing = pd.read_csv('df_missing.csv', index_col = 1)
current_df_missing
# Out:
#      Unnamed: 0   state  pop  debt
# year
# 2000        one    Ohio  1.5   NaN
# 2001        two    Ohio  1.7   NaN
# 2002      three    Ohio  3.6   NaN
# 2001       four  Nevada  2.4   NaN
# 2002       five  Nevada  2.9   NaN
# 2003        six  Nevada  3.2   NaN

# %% [markdown]
# # Manipulating Data
# ***set and reset index***

# %%
new_df_missing.set_index('Unnamed: 0') # not inplace- new DataFrame is created
# Out:
#             year   state  pop  debt
# Unnamed: 0
# one         2000    Ohio  1.5   NaN
# two         2001    Ohio  1.7   NaN
# three       2002    Ohio  3.6   NaN
# four        2001  Nevada  2.4   NaN
# five        2002  Nevada  2.9   NaN
# six         2003  Nevada  3.2   NaN

# %%
new_df_missing.set_index('Unnamed: 0', inplace = True) # DataFrame is modified _no new df is created

# %%
new_df_missing
# Out:
#             year   state  pop  debt
# Unnamed: 0
# one         2000    Ohio  1.5   NaN
# two         2001    Ohio  1.7   NaN
# three       2002    Ohio  3.6   NaN
# four        2001  Nevada  2.4   NaN
# five        2002  Nevada  2.9   NaN
# six         2003  Nevada  3.2   NaN

# %%
# Reset the index to default
new_df_missing.reset_index(inplace = True)

# %%
new_df_missing
# Out:
#   Unnamed: 0  year   state  pop  debt
# 0        one  2000    Ohio  1.5   NaN
# 1        two  2001    Ohio  1.7   NaN
# 2      three  2002    Ohio  3.6   NaN
# 3       four  2001  Nevada  2.4   NaN
# 4       five  2002  Nevada  2.9   NaN
# 5        six  2003  Nevada  3.2   NaN

# %%
new_df_missing.columns
# Out:
# Index(['Unnamed: 0', 'year', 'state', 'pop', 'debt'], dtype='object')

# %% [markdown]
# ***Rename Columns***

# %%
new_df_missing.rename(columns = {'Unnamed: 0': 'Number'}, inplace = True)
new_df_missing
# Out:
#   Number  year   state  pop  debt
# 0    one  2000    Ohio  1.5   NaN
# 1    two  2001    Ohio  1.7   NaN
# 2  three  2002    Ohio  3.6   NaN
# 3   four  2001  Nevada  2.4   NaN
# 4   five  2002  Nevada  2.9   NaN
# 5    six  2003  Nevada  3.2   NaN

# %%
new_df_missing.columns
# Out:
# Index(['Number', 'year', 'state', 'pop', 'debt'], dtype='object')

# %%
new_df_missing
# Out:
#   Number  year   state  pop  debt
# 0    one  2000    Ohio  1.5   NaN
# 1    two  2001    Ohio  1.7   NaN
# 2  three  2002    Ohio  3.6   NaN
# 3   four  2001  Nevada  2.4   NaN
# 4   five  2002  Nevada  2.9   NaN
# 5    six  2003  Nevada  3.2   NaN

# %%
# Let do more data cleaning
new_df_missing.rename({'year': 'Year', 'state':'State', 'pop':'Population', 'debt':'Debt'}, axis = 1, inplace = True)

# %%
new_df_missing
# Out:
#   Number  Year   State  Population  Debt
# 0    one  2000    Ohio         1.5   NaN
# 1    two  2001    Ohio         1.7   NaN
# 2  three  2002    Ohio         3.6   NaN
# 3   four  2001  Nevada         2.4   NaN
# 4   five  2002  Nevada         2.9   NaN
# 5    six  2003  Nevada         3.2   NaN

# %% [markdown]
# ***Reindexing***

# %%
new_df_missing.set_index('Number', inplace = True)
new_df_missing
# Out:
#         Year   State  Population  Debt
# Number
# one     2000    Ohio         1.5   NaN
# two     2001    Ohio         1.7   NaN
# three   2002    Ohio         3.6   NaN
# four    2001  Nevada         2.4   NaN
# five    2002  Nevada         2.9   NaN
# six     2003  Nevada         3.2   NaN

# %%
reverse_df_missing = new_df_missing.reindex(['six', 'five', 'four', 'three', 'two', 'one'])
reverse_df_missing
# Out:
#         Year   State  Population  Debt
# Number
# six     2003  Nevada         3.2   NaN
# five    2002  Nevada         2.9   NaN
# four    2001  Nevada         2.4   NaN
# three   2002    Ohio         3.6   NaN
# two     2001    Ohio         1.7   NaN
# one     2000    Ohio         1.5   NaN

# %% [markdown]
# ***Drop entries from Axis***

# %%
series_data
# Out:
# Names
# Bob        4
# Joe        4
# Will      -5
# Jeff     NaN
# Steve    ten
# Name: series_data, dtype: object

# %%
# Drop row from series
series_data.drop('Jeff') # not inplace
# Out:
# Names
# Bob        4
# Joe        4
# Will      -5
# Steve    ten
# Name: series_data, dtype: object

# %%
series_data.drop('Jeff', inplace = True)   # dropped inplace, from the memory

# %%
series_data
# Out:
# Names
# Bob        4
# Joe        4
# Will      -5
# Steve    ten
# Name: series_data, dtype: object

# %%
series_data.drop(['Joe', 'Steve'])
# Out:
# Names
# Bob      4
# Will    -5
# Name: series_data, dtype: object

# %%
# for DataFrames, we can drop from both axis - row=0 or columns =1
reverse_df_missing.drop('Year', axis=1)   # first way to drop the year
# Out:
#          State  Population  Debt
# Number
# six     Nevada         3.2   NaN
# five    Nevada         2.9   NaN
# four    Nevada         2.4   NaN
# three     Ohio         3.6   NaN
# two       Ohio         1.7   NaN
# one       Ohio         1.5   NaN

# %%
reverse_df_missing.drop(index = 'one')
# Out:
#         Year   State  Population  Debt
# Number
# six     2003  Nevada         3.2   NaN
# five    2002  Nevada         2.9   NaN
# four    2001  Nevada         2.4   NaN
# three   2002    Ohio         3.6   NaN
# two     2001    Ohio         1.7   NaN

# %%
reverse_df_missing.drop(columns = 'Year') # Second way to drop the year
# Out:
#          State  Population  Debt
# Number
# six     Nevada         3.2   NaN
# five    Nevada         2.9   NaN
# four    Nevada         2.4   NaN
# three     Ohio         3.6   NaN
# two       Ohio         1.7   NaN
# one       Ohio         1.5   NaN

# %%
reverse_df_missing.drop(columns =['Debt', 'Year'])
# Out:
#          State  Population
# Number
# six     Nevada         3.2
# five    Nevada         2.9
# four    Nevada         2.4
# three     Ohio         3.6
# two       Ohio         1.7
# one       Ohio         1.5

# %% [markdown]
# # 7^th september 2025

# %% [markdown]
# ***Sorting and Ranking***

# %%
# Sort index
series_data.sort_index()
# Out:
# Names
# Bob        4
# Joe        4
# Steve    ten
# Will      -5
# Name: series_data, dtype: object

# %%
series_data.sort_index(ascending = False)
# Out:
# Names
# Will      -5
# Steve    ten
# Joe        4
# Bob        4
# Name: series_data, dtype: object

# %%
#series_data.sort_values()    # since we have mixed string and integers, it wont sort

# %%
series_int.sort_values()
# Out:
# 0     2
# 3     3
# 2     4
# 4     5
# 5     8
# 1     9
# 6    12
# dtype: int64

# %%
series_int #Unsorted
# Out:
# 0     2
# 1     9
# 2     4
# 3     3
# 4     5
# 5     8
# 6    12
# dtype: int64

# %%
series_int.sort_values(ascending = False)   # this means its doing in descending order
# Out:
# 6    12
# 1     9
# 5     8
# 4     5
# 2     4
# 3     3
# 0     2
# dtype: int64

# %%
df
# Out:
#    year   state  pop capital city Location
# 0  2000    Ohio  1.5     columbia  America
# 1  2001    Ohio  1.7     columbia  America
# 2  2002    Ohio  3.6     columbia  America
# 3  2001  Nevada  2.4  carson city  America
# 4  2002  Nevada  2.9  carson city  America
# 5  2003  Nevada  3.2  carson city  America

# %%
df.sort_index(ascending = False)
# Out:
#    year   state  pop capital city Location
# 5  2003  Nevada  3.2  carson city  America
# 4  2002  Nevada  2.9  carson city  America
# 3  2001  Nevada  2.4  carson city  America
# 2  2002    Ohio  3.6     columbia  America
# 1  2001    Ohio  1.7     columbia  America
# 0  2000    Ohio  1.5     columbia  America

# %%
df.sort_index(axis = 1)
# Out:
#   Location capital city  pop   state  year
# 0  America     columbia  1.5    Ohio  2000
# 1  America     columbia  1.7    Ohio  2001
# 2  America     columbia  3.6    Ohio  2002
# 3  America  carson city  2.4  Nevada  2001
# 4  America  carson city  2.9  Nevada  2002
# 5  America  carson city  3.2  Nevada  2003

# %%
df.sort_values('pop', axis=0)
# Out:
#    year   state  pop capital city Location
# 0  2000    Ohio  1.5     columbia  America
# 1  2001    Ohio  1.7     columbia  America
# 3  2001  Nevada  2.4  carson city  America
# 4  2002  Nevada  2.9  carson city  America
# 5  2003  Nevada  3.2  carson city  America
# 2  2002    Ohio  3.6     columbia  America

# %%
series_na = pd.Series([4, np.nan, 7, np.nan, -3, 2])
series_na
# Out:
# 0    4.0
# 1    NaN
# 2    7.0
# 3    NaN
# 4   -3.0
# 5    2.0
# dtype: float64

# %%
series_na.sort_values()
# Out:
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# 1    NaN
# 3    NaN
# dtype: float64

# %%
# rank
series_to_rank = pd.Series([7, -5, 7, 4, 2, 0, 4])
series_to_rank
# Out:
# 0    7
# 1   -5
# 2    7
# 3    4
# 4    2
# 5    0
# 6    4
# dtype: int64

# %%
series_to_rank.rank()
# Out:
# 0    6.5
# 1    1.0
# 2    6.5
# 3    4.5
# 4    3.0
# 5    2.0
# 6    4.5
# dtype: float64

# %%
series_to_rank.rank(method = 'dense')
# Out:
# 0    5.0
# 1    1.0
# 2    5.0
# 3    4.0
# 4    3.0
# 5    2.0
# 6    4.0
# dtype: float64

# %%
series_to_rank.rank(method = 'first')
# Out:
# 0    6.0
# 1    1.0
# 2    7.0
# 3    4.0
# 4    3.0
# 5    2.0
# 6    5.0
# dtype: float64

# %% [markdown]
# ***Summarizing, Aggregating and Descriptive Statistics***

# %%
df_num = pd.DataFrame([[1.4, np.nan],
                      [7.1, -4.5],
                      [np.nan, np.nan], 
                      [0.75, -1.3]], 
                      index = ['a', 'b', 'c', 'd'],
                      columns = ['one', 'two'])
df_num
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
# Sum()
df_num.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df_num.sum(axis = 'columns')
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
# idxmin()  #gives index with the minimum value
df_num.idxmin()
# Out:
# one    d
# two    b
# dtype: object

# %%
df_num.idxmin(axis = 1)
# Out:
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\3708138188.py:1: FutureWarning: The behavior of DataFrame.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   df_num.idxmin(axis = 1)
# a    one
# b    two
# c    NaN
# d    two
# dtype: object

# %%
# df.cumsum()
df_num.cumsum()
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
df_num.describe()   # this returns descriptive statistics
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.describe(include = 'O')
# Out:
#           Make Colour      Price
# count       10     10         10
# unique       4      5          9
# top     Toyota  White  $7,000.00
# freq         4      4          2

# %%
# Methods for series- unique(), value_counts(), isin()
series = pd.Series(['c', 'a', 'd', 'a', 'b', 'c', 'c'])
series
# Out:
# 0    c
# 1    a
# 2    d
# 3    a
# 4    b
# 5    c
# 6    c
# dtype: object

# %%
# returns unique values
series.unique()
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
series.value_counts()
# Out:
# c    3
# a    2
# d    1
# b    1
# Name: count, dtype: int64

# %%
series.value_counts(ascending = True)
# Out:
# d    1
# b    1
# a    2
# c    3
# Name: count, dtype: int64

# %%
# isin
mask = series.isin(['d', 'c'])
mask
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %%
series[mask]
# Out:
# 0    c
# 2    d
# 5    c
# 6    c
# dtype: object

# %%
car_sales_clean = pd.read_csv('car_sales_clean.csv')
car_sales_clean
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %% [markdown]
# ## 13^th september 2025

# %%
# pd.groupby()
car_sales_clean['Price'].groupby(car_sales_clean['Colour'])

# %%
car_sales.groupby('Colour')['Price']

# %%
list(car_sales_clean['Price'].groupby(car_sales_clean['Colour']))
# Out:
# [('Black',
#   3    22000.0
#   Name: Price, dtype: float64),
#  ('Blue',
#   2    7000.0
#   6    7500.0
#   7    7000.0
#   Name: Price, dtype: float64),
#  ('Green',
#   5    4500.0
#   Name: Price, dtype: float64),
#  ('Red',
#   1    5000.0
#   Name: Price, dtype: float64),
#  ('White',
#   0    4000.0
#   4    3500.0
#   8    6250.0
#   9    9700.0
#   Name: Price, dtype: float64)]

# %%
car_sales_clean['Price'].groupby(car_sales_clean['Colour']).sum()
# Out:
# Colour
# Black    22000.0
# Blue     21500.0
# Green     4500.0
# Red       5000.0
# White    23450.0
# Name: Price, dtype: float64

# %%
grouped = car_sales_clean['Price'].groupby(car_sales_clean['Colour'])

# %%
grouped.sum()
# Out:
# Colour
# Black    22000.0
# Blue     21500.0
# Green     4500.0
# Red       5000.0
# White    23450.0
# Name: Price, dtype: float64

# %%
# Group the data with multiple columns
new_grouped = car_sales_clean['Price'].groupby([car_sales_clean['Make'], car_sales_clean['Colour']])
new_grouped

# %%
list(new_grouped)
# Out:
# [(('BMW', 'Black'),
#   3    22000.0
#   Name: Price, dtype: float64),
#  (('Honda', 'Blue'),
#   6    7500.0
#   7    7000.0
#   Name: Price, dtype: float64),
#  (('Honda', 'Red'),
#   1    5000.0
#   Name: Price, dtype: float64),
#  (('Nissan', 'White'),
#   4    3500.0
#   9    9700.0
#   Name: Price, dtype: float64),
#  (('Toyota', 'Blue'),
#   2    7000.0
#   Name: Price, dtype: float64),
#  (('Toyota', 'Green'),
#   5    4500.0
#   Name: Price, dtype: float64),
#  (('Toyota', 'White'),
#   0    4000.0
#   8    6250.0
#   Name: Price, dtype: float64)]

# %%
new_grouped.mean()
# Out:
# Make    Colour
# BMW     Black     22000.0
# Honda   Blue       7250.0
#         Red        5000.0
# Nissan  White      6600.0
# Toyota  Blue       7000.0
#         Green      4500.0
#         White      5125.0
# Name: Price, dtype: float64

# %%
new_grouped.sum()
# Out:
# Make    Colour
# BMW     Black     22000.0
# Honda   Blue      14500.0
#         Red        5000.0
# Nissan  White     13200.0
# Toyota  Blue       7000.0
#         Green      4500.0
#         White     10250.0
# Name: Price, dtype: float64

# %%
new_grouped.count()
# Out:
# Make    Colour
# BMW     Black     1
# Honda   Blue      2
#         Red       1
# Nissan  White     2
# Toyota  Blue      1
#         Green     1
#         White     2
# Name: Price, dtype: int64

# %%
car_sales_clean.groupby(['Make', 'Colour'])['Price'].mean()
# Out:
# Make    Colour
# BMW     Black     22000.0
# Honda   Blue       7250.0
#         Red        5000.0
# Nissan  White      6600.0
# Toyota  Blue       7000.0
#         Green      4500.0
#         White      5125.0
# Name: Price, dtype: float64

# %% [markdown]
# * Class Acrivity: calculate the average odometer reading per make of car and total price

# %%
car_sales_clean
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
Average_odometer = car_sales_clean.groupby('Odometer (KM)')['Price'].mean()
Average_odometer
# Out:
# Odometer (KM)
# 11179     22000.0
# 31600      9700.0
# 32549      7000.0
# 45698      7500.0
# 54738      7000.0
# 60000      6250.0
# 87899      5000.0
# 99213      4500.0
# 150043     4000.0
# 213095     3500.0
# Name: Price, dtype: float64

# %%
Average_odometer = car_sales_clean.groupby('Price')['Odometer (KM)'].mean()
Average_odometer
# Out:
# Price
# 3500.0     213095.0
# 4000.0     150043.0
# 4500.0      99213.0
# 5000.0      87899.0
# 6250.0      60000.0
# 7000.0      43643.5
# 7500.0      45698.0
# 9700.0      31600.0
# 22000.0     11179.0
# Name: Odometer (KM), dtype: float64

# %%
average_odometer_make = car_sales_clean.groupby ('Make')['Odometer (KM)'].mean()
average_odometer_make
# Out:
# Make
# BMW        11179.000000
# Honda      62778.333333
# Nissan    122347.500000
# Toyota     85451.250000
# Name: Odometer (KM), dtype: float64

# %%
car_sales_clean.groupby(['Make', 'Odometer (KM)'])['Price'].mean()
# Out:
# Make    Odometer (KM)
# BMW     11179            22000.0
# Honda   45698             7500.0
#         54738             7000.0
#         87899             5000.0
# Nissan  31600             9700.0
#         213095            3500.0
# Toyota  32549             7000.0
#         60000             6250.0
#         99213             4500.0
#         150043            4000.0
# Name: Price, dtype: float64

# %%
average_odometer_per_make = car_sales_clean.groupby('Make')['Odometer (KM)'].mean()
average_odometer_per_make
# Out:
# Make
# BMW        11179.000000
# Honda      62778.333333
# Nissan    122347.500000
# Toyota     85451.250000
# Name: Odometer (KM), dtype: float64

# %%
total_price_per_make = car_sales_clean.groupby('Make')['Price'].sum()
total_price_per_make
# Out:
# Make
# BMW       22000.0
# Honda     19500.0
# Nissan    13200.0
# Toyota    21750.0
# Name: Price, dtype: float64

# %%
# Pivot and cross-tab
tips = pd.read_csv('tip.csv')

# %%
tips.head
# Out:
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.pivot_table(index=['sex','time','smoker','day'], values = ['tip', 'size','total_bill'] )
# Out:
#                                size       tip  total_bill
# sex    time   smoker day
# Female Dinner No     Fri   2.000000  3.250000   22.750000
#                      Sat   2.307692  2.724615   19.003846
#                      Sun   3.071429  3.329286   20.824286
#                      Thur  2.000000  3.000000   18.780000
#               Yes    Fri   2.000000  2.700000   12.200000
#                      Sat   2.200000  2.868667   20.266667
#                      Sun   2.500000  3.500000   16.540000
#        Lunch  No     Fri   3.000000  3.000000   15.980000
#                      Thur  2.500000  2.437083   15.899167
#               Yes    Fri   2.000000  2.660000   13.260000
#                      Thur  2.428571  2.990000   19.218571
# Male   Dinner No     Fri   2.000000  2.500000   17.475000
#                      Sat   2.656250  3.256563   19.929063
#                      Sun   2.883721  3.115349   20.403256
#               Yes    Fri   2.400000  3.246000   25.892000
# ...

# %%
tips.pivot_table(index=['sex','day'], values=['tip', 'size','total_bill'] )
# Out:
#                  size       tip  total_bill
# sex    day
# Female Fri   2.111111  2.781111   14.145556
#        Sat   2.250000  2.801786   19.680357
#        Sun   2.944444  3.367222   19.872222
#        Thur  2.468750  2.575625   16.715312
# Male   Fri   2.100000  2.693000   19.857000
#        Sat   2.644068  3.083898   20.802542
#        Sun   2.810345  3.220345   21.887241
#        Thur  2.433333  2.980333   18.714667

# %%
tips.pivot_table(['tip', 'size','total_bill'] ,index=['sex','day'], columns='time', margins = False)
# Out:
#                  size                 tip           total_bill
# time           Dinner     Lunch    Dinner     Lunch     Dinner      Lunch
# sex    day
# Female Fri   2.000000  2.250000  2.810000  2.745000  14.310000  13.940000
#        Sat   2.250000       NaN  2.801786       NaN  19.680357        NaN
#        Sun   2.944444       NaN  3.367222       NaN  19.872222        NaN
#        Thur  2.000000  2.483871  3.000000  2.561935  18.780000  16.648710
# Male   Fri   2.285714  1.666667  3.032857  1.900000  23.487143  11.386667
#        Sat   2.644068       NaN  3.083898       NaN  20.802542        NaN
#        Sun   2.810345       NaN  3.220345       NaN  21.887241        NaN
#        Thur       NaN  2.433333       NaN  2.980333        NaN  18.714667

# %%
tips.pivot_table(['tip', 'size','total_bill'] ,index=['sex','day'], columns='time', margins = True)
# Out:
#                  size                           tip                      \
# time           Dinner     Lunch       All    Dinner     Lunch       All
# sex    day
# Female Fri   2.000000  2.250000  2.111111  2.810000  2.745000  2.781111
#        Sat   2.250000       NaN  2.250000  2.801786       NaN  2.801786
#        Sun   2.944444       NaN  2.944444  3.367222       NaN  3.367222
#        Thur  2.000000  2.483871  2.468750  3.000000  2.561935  2.575625
# Male   Fri   2.285714  1.666667  2.100000  3.032857  1.900000  2.693000
#        Sat   2.644068       NaN  2.644068  3.083898       NaN  3.083898
#        Sun   2.810345       NaN  2.810345  3.220345       NaN  3.220345
#        Thur       NaN  2.433333  2.433333       NaN  2.980333  2.980333
# All          2.630682  2.411765  2.569672  3.102670  2.728088  2.998279
#
#             total_bill
# time            Dinner      Lunch        All
# sex    day
# Female Fri   14.310000  13.940000  14.145556
# ...

# %%
tips.pivot_table(index=['day', 'smoker'], values = ['total_bill', 'tip', 'size'])
# Out:
#                  size       tip  total_bill
# day  smoker
# Fri  No      2.250000  2.812500   18.420000
#      Yes     2.066667  2.714000   16.813333
# Sat  No      2.555556  3.102889   19.661778
#      Yes     2.476190  2.875476   21.276667
# Sun  No      2.929825  3.167895   20.506667
#      Yes     2.578947  3.516842   24.120000
# Thur No      2.488889  2.673778   17.113111
#      Yes     2.352941  3.030000   19.190588

# %%
tips.pivot_table(['tip', 'size'], index = ['time', 'day'], columns = 'smoker')
# Out:
#                  size                 tip
# smoker             No       Yes        No       Yes
# time   day
# Dinner Fri   2.000000  2.222222  2.750000  3.003333
#        Sat   2.555556  2.476190  3.102889  2.875476
#        Sun   2.929825  2.578947  3.167895  3.516842
#        Thur  2.000000       NaN  3.000000       NaN
# Lunch  Fri   3.000000  1.833333  3.000000  2.280000
#        Thur  2.500000  2.352941  2.666364  3.030000

# %%
tips.pivot_table(['tip', 'size'], index = ['time', 'day'], columns = 'smoker', margins = True)
# Out:
#                  size                           tip
# smoker             No       Yes       All        No       Yes       All
# time   day
# Dinner Fri   2.000000  2.222222  2.166667  2.750000  3.003333  2.940000
#        Sat   2.555556  2.476190  2.517241  3.102889  2.875476  2.993103
#        Sun   2.929825  2.578947  2.842105  3.167895  3.516842  3.255132
#        Thur  2.000000       NaN  2.000000  3.000000       NaN  3.000000
# Lunch  Fri   3.000000  1.833333  2.000000  3.000000  2.280000  2.382857
#        Thur  2.500000  2.352941  2.459016  2.666364  3.030000  2.767705
# All          2.668874  2.408602  2.569672  2.991854  3.008710  2.998279

# %%
# Chnage the aggregation count
tips.pivot_table(['tip', 'size'], index = ['time', 'day'],
                 columns = 'smoker', aggfunc ='count', margins=True)
# Out:
#               size               tip
# smoker          No   Yes  All     No   Yes  All
# time   day
# Dinner Fri     3.0   9.0   12    3.0   9.0   12
#        Sat    45.0  42.0   87   45.0  42.0   87
#        Sun    57.0  19.0   76   57.0  19.0   76
#        Thur    1.0   NaN    1    1.0   NaN    1
# Lunch  Fri     1.0   6.0    7    1.0   6.0    7
#        Thur   44.0  17.0   61   44.0  17.0   61
# All          151.0  93.0  244  151.0  93.0  244

# %%
tips.pivot_table(['tip', 'size'], index = ['time', 'day'],
                 columns = 'smoker', aggfunc ='sum', margins=True)
# Out:
#               size                 tip
# smoker          No    Yes  All      No     Yes     All
# time   day
# Dinner Fri     6.0   20.0   26    8.25   27.03   35.28
#        Sat   115.0  104.0  219  139.63  120.77  260.40
#        Sun   167.0   49.0  216  180.57   66.82  247.39
#        Thur    2.0    NaN    2    3.00     NaN    3.00
# Lunch  Fri     3.0   11.0   14    3.00   13.68   16.68
#        Thur  110.0   40.0  150  117.32   51.51  168.83
# All          403.0  224.0  627  451.77  279.81  731.58

# %%
#Using cross tab magix
pd.crosstab(index = [tips.time, tips.day], columns =tips.smoker, margins = True)
# Out:
# smoker        No  Yes  All
# time   day
# Dinner Fri     3    9   12
#        Sat    45   42   87
#        Sun    57   19   76
#        Thur    1    0    1
# Lunch  Fri     1    6    7
#        Thur   44   17   61
# All          151   93  244

# %% [markdown]
# # 14^th sept 2025

# %% [markdown]
# # Data cleaning and wrangling

# %% [markdown]
# * Handling missing data

# %%
# Find if there is missing data
df_missing.isna()
# Out:
#         year  state    pop  debt
# one    False  False  False  True
# two    False  False  False  True
# three  False  False  False  True
# four   False  False  False  True
# five   False  False  False  True
# six    False  False  False  True

# %%
df_missing.isna().sum()  # This way you are able to have all data summed with missing values
# Out:
# year     0
# state    0
# pop      0
# debt     6
# dtype: int64

# %%
df_missing.isnull()
# Out:
#         year  state    pop  debt
# one    False  False  False  True
# two    False  False  False  True
# three  False  False  False  True
# four   False  False  False  True
# five   False  False  False  True
# six    False  False  False  True

# %%
df_missing.isnull().sum()
# Out:
# year     0
# state    0
# pop      0
# debt     6
# dtype: int64

# %%
taxis = pd.read_csv('taxis_csv.csv')
taxis.head()
# Out:
#              pickup           dropoff  passengers  distance  fare   tip  \
# 0  23/03/2019 20:21  23/03/2019 20:27           1      1.60   7.0  2.15
# 1  04/03/2019 16:11  04/03/2019 16:19           1      0.79   5.0  0.00
# 2  27/03/2019 17:53  27/03/2019 18:00           1      1.37   7.5  2.36
# 3  10/03/2019 01:23  10/03/2019 01:49           1      7.70  27.0  6.15
# 4  30/03/2019 13:27  30/03/2019 13:37           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# ...

# %%
taxis.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
taxis.describe()
# Out:
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# std       1.203768     3.827867    11.551804     2.44856     1.415267
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
#
#              total
# count  6433.000000
# mean     18.517794
# std      13.815570
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000

# %%
taxis.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
taxis.tail(20)
# Out:
#                 pickup           dropoff  passengers  distance   fare   tip  \
# 6413  22/03/2019 14:28  22/03/2019 14:52           1      4.00  13.61  0.00
# 6414  30/03/2019 14:04  30/03/2019 14:18           2      2.60  11.00  2.91
# 6415  03/03/2019 08:42  03/03/2019 08:46           1      0.89   5.00  0.00
# 6416  19/03/2019 17:27  19/03/2019 18:41           1      7.93  21.08  0.00
# 6417  10/03/2019 12:10  10/03/2019 12:43           2     11.17  35.00  0.00
# 6418  02/03/2019 21:47  02/03/2019 21:55           1      1.48   7.50  1.76
# 6419  16/03/2019 10:37  16/03/2019 10:47           1      1.54   8.50  0.00
# 6420  16/03/2019 15:39  16/03/2019 15:46           2      1.20   7.00  0.00
# 6421  24/03/2019 09:07  24/03/2019 09:36           6     10.23  33.00  0.00
# 6422  22/03/2019 20:17  22/03/2019 20:36           1      4.02  16.00  0.00
# 6423  12/03/2019 08:10  12/03/2019 08:35           1      4.30  18.50  0.00
# ...

# %%
taxis.dropna(axis=1)
# Out:
#                 pickup           dropoff  passengers  distance  fare   tip  \
# 0     23/03/2019 20:21  23/03/2019 20:27           1      1.60   7.0  2.15
# 1     04/03/2019 16:11  04/03/2019 16:19           1      0.79   5.0  0.00
# 2     27/03/2019 17:53  27/03/2019 18:00           1      1.37   7.5  2.36
# 3     10/03/2019 01:23  10/03/2019 01:49           1      7.70  27.0  6.15
# 4     30/03/2019 13:27  30/03/2019 13:37           3      2.16   9.0  1.10
# ...                ...               ...         ...       ...   ...   ...
# 6428  31/03/2019 09:51  31/03/2019 09:55           1      0.75   4.5  1.06
# 6429  31/03/2019 17:38  31/03/2019 18:34           1     18.74  58.0  0.00
# 6430  23/03/2019 22:55  23/03/2019 23:14           1      4.14  16.0  0.00
# 6431  04/03/2019 10:09  04/03/2019 10:14           1      1.12   6.0  0.00
# 6432  13/03/2019 19:31  13/03/2019 19:48           1      3.85  15.0  3.36
#
#       tolls  total   color
# 0       0.0  12.95  yellow
# ...

# %%
# dropna- rows  
taxis.dropna(axis=1).info()  #This drops the columns with the missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pickup      6433 non-null   object
#  1   dropoff     6433 non-null   object
#  2   passengers  6433 non-null   int64
#  3   distance    6433 non-null   float64
#  4   fare        6433 non-null   float64
#  5   tip         6433 non-null   float64
#  6   tolls       6433 non-null   float64
#  7   total       6433 non-null   float64
#  8   color       6433 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 452.4+ KB

# %%
taxis.dropna(axis=0).info  #This drops the rows with missing values
# Out:
# <bound method DataFrame.info of                 pickup           dropoff  passengers  distance  fare   tip  \
# 0     23/03/2019 20:21  23/03/2019 20:27           1      1.60   7.0  2.15
# 1     04/03/2019 16:11  04/03/2019 16:19           1      0.79   5.0  0.00
# 2     27/03/2019 17:53  27/03/2019 18:00           1      1.37   7.5  2.36
# 3     10/03/2019 01:23  10/03/2019 01:49           1      7.70  27.0  6.15
# 4     30/03/2019 13:27  30/03/2019 13:37           3      2.16   9.0  1.10
# ...                ...               ...         ...       ...   ...   ...
# 6428  31/03/2019 09:51  31/03/2019 09:55           1      0.75   4.5  1.06
# 6429  31/03/2019 17:38  31/03/2019 18:34           1     18.74  58.0  0.00
# 6430  23/03/2019 22:55  23/03/2019 23:14           1      4.14  16.0  0.00
# 6431  04/03/2019 10:09  04/03/2019 10:14           1      1.12   6.0  0.00
# 6432  13/03/2019 19:31  13/03/2019 19:48           1      3.85  15.0  3.36
#
# ...

# %%
df_missing.dropna(axis=1, how='all')
# Out:
#        year   state  pop
# one    2000    Ohio  1.5
# two    2001    Ohio  1.7
# three  2002    Ohio  3.6
# four   2001  Nevada  2.4
# five   2002  Nevada  2.9
# six    2003  Nevada  3.2

# %%
#Select columns to drop rows from
taxis.dropna(subset=['dropoff_zone', 'dropoff_borough'],axis =0).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6388 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6388 non-null   object
#  1   dropoff          6388 non-null   object
#  2   passengers       6388 non-null   int64
#  3   distance         6388 non-null   float64
#  4   fare             6388 non-null   float64
#  5   tip              6388 non-null   float64
#  6   tolls            6388 non-null   float64
#  7   total            6388 non-null   float64
#  8   color            6388 non-null   object
#  9   payment          6345 non-null   object
#  10  pickup_zone      6383 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6383 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 748.6+ KB

# %%
6433-6388
# Out:
# 45

# %%
# usually you drop rows to clean the dataset
taxis.dropna(inplace = True)

# %%
taxis.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
 # Fill values
taxis_2 = pd.read_csv('taxis_csv.csv')
taxis_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
# you can fill with specific values, average, max or median
taxis_2.fillna(0)
# Out:
#                 pickup           dropoff  passengers  distance  fare   tip  \
# 0     23/03/2019 20:21  23/03/2019 20:27           1      1.60   7.0  2.15
# 1     04/03/2019 16:11  04/03/2019 16:19           1      0.79   5.0  0.00
# 2     27/03/2019 17:53  27/03/2019 18:00           1      1.37   7.5  2.36
# 3     10/03/2019 01:23  10/03/2019 01:49           1      7.70  27.0  6.15
# 4     30/03/2019 13:27  30/03/2019 13:37           3      2.16   9.0  1.10
# ...                ...               ...         ...       ...   ...   ...
# 6428  31/03/2019 09:51  31/03/2019 09:55           1      0.75   4.5  1.06
# 6429  31/03/2019 17:38  31/03/2019 18:34           1     18.74  58.0  0.00
# 6430  23/03/2019 22:55  23/03/2019 23:14           1      4.14  16.0  0.00
# 6431  04/03/2019 10:09  04/03/2019 10:14           1      1.12   6.0  0.00
# 6432  13/03/2019 19:31  13/03/2019 19:48           1      3.85  15.0  3.36
#
#       tolls  total   color      payment            pickup_zone  \
# ...

# %%
taxis_2.fillna(0).isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
taxis_2.fillna({9:'No Payment', 10:'No record', 11:'Not applicable',12:'No record', 13:'Not Applicable'})
# Out:
#                 pickup           dropoff  passengers  distance  fare   tip  \
# 0     23/03/2019 20:21  23/03/2019 20:27           1      1.60   7.0  2.15
# 1     04/03/2019 16:11  04/03/2019 16:19           1      0.79   5.0  0.00
# 2     27/03/2019 17:53  27/03/2019 18:00           1      1.37   7.5  2.36
# 3     10/03/2019 01:23  10/03/2019 01:49           1      7.70  27.0  6.15
# 4     30/03/2019 13:27  30/03/2019 13:37           3      2.16   9.0  1.10
# ...                ...               ...         ...       ...   ...   ...
# 6428  31/03/2019 09:51  31/03/2019 09:55           1      0.75   4.5  1.06
# 6429  31/03/2019 17:38  31/03/2019 18:34           1     18.74  58.0  0.00
# 6430  23/03/2019 22:55  23/03/2019 23:14           1      4.14  16.0  0.00
# 6431  04/03/2019 10:09  04/03/2019 10:14           1      1.12   6.0  0.00
# 6432  13/03/2019 19:31  13/03/2019 19:48           1      3.85  15.0  3.36
#
#       tolls  total   color      payment            pickup_zone  \
# ...

# %%
taxis_2.fillna({'payment':'No Payment', 'pickup_zone':'No record', 'dropoff_zone':'Not applicable',
                'pickup_borough':'No record', 'dropoff_borough':'Not Applicable'}, inplace = True)

# %%
taxis_2['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# No Payment       44
# Name: count, dtype: int64

# %%
taxis_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   object
#  1   dropoff          6433 non-null   object
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6433 non-null   object
#  10  pickup_zone      6433 non-null   object
#  11  dropoff_zone     6433 non-null   object
#  12  pickup_borough   6433 non-null   object
#  13  dropoff_borough  6433 non-null   object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 703.7+ KB

# %%
# Check the imputation
taxis_2['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# No Payment       44
# Name: count, dtype: int64

# %%
# fill with mean/average
df_missing.fillna(df_missing['pop'].mean())
# Out:
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\2920549529.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_missing.fillna(df_missing['pop'].mean())
#        year   state  pop  debt
# one    2000    Ohio  1.5  2.55
# two    2001    Ohio  1.7  2.55
# three  2002    Ohio  3.6  2.55
# four   2001  Nevada  2.4  2.55
# five   2002  Nevada  2.9  2.55
# six    2003  Nevada  3.2  2.55

# %%
df_missing
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
df_missing.fillna(df_missing['pop'].median())
# Out:
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\88530380.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_missing.fillna(df_missing['pop'].median())
#        year   state  pop  debt
# one    2000    Ohio  1.5  2.65
# two    2001    Ohio  1.7  2.65
# three  2002    Ohio  3.6  2.65
# four   2001  Nevada  2.4  2.65
# five   2002  Nevada  2.9  2.65
# six    2003  Nevada  3.2  2.65

# %%
df_missing.fillna(df_missing['pop'].max())
# Out:
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\67045718.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_missing.fillna(df_missing['pop'].max())
#        year   state  pop  debt
# one    2000    Ohio  1.5   3.6
# two    2001    Ohio  1.7   3.6
# three  2002    Ohio  3.6   3.6
# four   2001  Nevada  2.4   3.6
# five   2002  Nevada  2.9   3.6
# six    2003  Nevada  3.2   3.6

# %%
# Forward fill and backward fill - ffill & bfill
df = pd.DataFrame(np.random.randn(6,3))
df.iloc[2:5, 1] =np.nan
df.iloc[4:, 2] =np.nan
df
# Out:
#           0         1         2
# 0 -1.392559 -0.029686  1.116577
# 1  1.686418  0.618994  0.604537
# 2 -1.822184       NaN  2.262824
# 3 -0.117215       NaN -0.613925
# 4  0.246934       NaN       NaN
# 5  0.245673  0.122903       NaN

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#           0         1         2
# 0 -1.392559 -0.029686  1.116577
# 1  1.686418  0.618994  0.604537
# 2 -1.822184  0.618994  2.262824
# 3 -0.117215  0.618994 -0.613925
# 4  0.246934  0.618994 -0.613925
# 5  0.245673  0.122903 -0.613925

# %%
df.fillna(method='bfill')
# Out:
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#           0         1         2
# 0 -1.392559 -0.029686  1.116577
# 1  1.686418  0.618994  0.604537
# 2 -1.822184  0.122903  2.262824
# 3 -0.117215  0.122903 -0.613925
# 4  0.246934  0.122903       NaN
# 5  0.245673  0.122903       NaN

# %%
df.ffill()
# Out:
#           0         1         2
# 0 -1.392559 -0.029686  1.116577
# 1  1.686418  0.618994  0.604537
# 2 -1.822184  0.618994  2.262824
# 3 -0.117215  0.618994 -0.613925
# 4  0.246934  0.618994 -0.613925
# 5  0.245673  0.122903 -0.613925

# %%
df.bfill()
# Out:
#           0         1         2
# 0 -1.392559 -0.029686  1.116577
# 1  1.686418  0.618994  0.604537
# 2 -1.822184  0.122903  2.262824
# 3 -0.117215  0.122903 -0.613925
# 4  0.246934  0.122903       NaN
# 5  0.245673  0.122903       NaN

# %% [markdown]
# ## Data Transformation

# %%
# Remove duplicates
data = pd.DataFrame({'k':['one', 'two']*3 + ['two'],
                     'k2':[1,1,2,3,3,4,4,]})
data
# Out:
#      k  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#      k  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data.drop_duplicates()
# Out:
#      k  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %% [markdown]
# > Both of these methods by default consider all the columns. Alternatively you can specify the columns to detect using subset parameter

# %%
# Add one more column
data ['v1']=range(7)
data
# Out:
#      k  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates('k')
# Out:
#      k  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
data.drop_duplicates('k2')
# Out:
#      k  k2  v1
# 0  one   1   0
# 2  one   2   2
# 3  two   3   3
# 5  two   4   5

# %%
data.drop_duplicates('k2', keep='last')
# Out:
#      k  k2  v1
# 1  two   1   1
# 2  one   2   2
# 4  one   3   4
# 6  two   4   6

# %%
# Transform with function or mapping (map() & apply())
food_type = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'pastrami', 'corned beef', 'bacon', 'pastrami',
                                    'honey ham', 'nova lox'],
                         '0unces':[4,3,12,6,7.5,8,3,5,6]})
food_type
# Out:
#           food  0unces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {'bacon': 'pig',
                  'pulled pork':'pig',
                  'pastrami': 'cow',
                  'corned beef': 'cow',
                  'honey ham': 'cow',
                  'nova lox': 'salmon'}

# %%
food_type['animal'] = food_type['food'].map(meat_to_animal)
food_type
# Out:
#           food  0unces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     cow
# 8     nova lox     6.0  salmon

# %%
df
# Out:
#           0         1         2
# 0 -1.392559 -0.029686  1.116577
# 1  1.686418  0.618994  0.604537
# 2 -1.822184       NaN  2.262824
# 3 -0.117215       NaN -0.613925
# 4  0.246934       NaN       NaN
# 5  0.245673  0.122903       NaN

# %%
df.apply(lambda x:x**2)
# Out:
#           0         1         2
# 0  1.939220  0.000881  1.246744
# 1  2.844005  0.383154  0.365465
# 2  3.320354       NaN  5.120371
# 3  0.013739       NaN  0.376903
# 4  0.060976       NaN       NaN
# 5  0.060355  0.015105       NaN

# %%
df.apply(np.sum, axis = 1)
# Out:
# 0   -0.305668
# 1    2.909949
# 2    0.440640
# 3   -0.731140
# 4    0.246934
# 5    0.368576
# dtype: float64

# %%
df[3] = df[2].apply(lambda x: x+2)

# %%
df
# Out:
#           0         1         2         3
# 0 -1.392559 -0.029686  1.116577  3.116577
# 1  1.686418  0.618994  0.604537  2.604537
# 2 -1.822184       NaN  2.262824  4.262824
# 3 -0.117215       NaN -0.613925  1.386075
# 4  0.246934       NaN       NaN       NaN
# 5  0.245673  0.122903       NaN       NaN

# %% [markdown]
# * String manipulation

# %%
string = 'this,is,a,string,  test'
string
# Out:
# 'this,is,a,string,  test'

# %%
#split
string.split(',')
# Out:
# ['this', 'is', 'a', 'string', '  test']

# %%
# Use strip() to whitespace
words = [x.strip() for x in string.split(',')]

# %%
words
# Out:
# ['this', 'is', 'a', 'string', 'test']

# %%
first, second, third, fourth,fifth = words

# %%
# Concatenate with '::' using +
first + '::' +second +'::' +third + '::' + fourth + '::' + fifth
# Out:
# 'this::is::a::string::test'

# %%
# join()
'::'.join(words)
# Out:
# 'this::is::a::string::test'

# %%
# locate substrings
"that" in string
# Out:
# False

# %%
string.find('is')
# Out:
# 2

# %%
string.index('is')
# Out:
# 2

# %%
#string.index(':')

# %%
string.find(':')
# Out:
# -1

# %%
string.count(',')
# Out:
# 4

# %%
string.replace(',', ' ')
# Out:
# 'this is a string   test'

# %%
car_sales_dirty = pd.read_csv('car-sales.csv')
car_sales_dirty
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales_dirty.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales_dirty['Price'] = car_sales_dirty['Price'].replace({'\$': '', ',':''}, regex=True).astype(float)
car_sales_dirty['Price']
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\1365087683.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales_dirty['Price'] = car_sales_dirty['Price'].replace({'\$': '', ',':''}, regex=True).astype(float)
# 0     4000.0
# 1     5000.0
# 2     7000.0
# 3    22000.0
# 4     3500.0
# 5     4500.0
# 6     7500.0
# 7     7000.0
# 8     6250.0
# 9     9700.0
# Name: Price, dtype: float64

# %%
car_sales_dirty['Price'] = car_sales_dirty['Price'].replace({'\$': '', ',':''}, regex=True).astype(int)
car_sales_dirty['Price']
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\3234354429.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales_dirty['Price'] = car_sales_dirty['Price'].replace({'\$': '', ',':''}, regex=True).astype(int)
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
car_sales_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     int32
# dtypes: int32(1), int64(2), object(2)
# memory usage: 492.0+ bytes

# %%
car_sales_dirty.describe()
# Out:
#        Odometer (KM)      Doors         Price
# count      10.000000  10.000000     10.000000
# mean    78601.400000   4.000000   7645.000000
# std     61983.471735   0.471405   5379.407753
# min     11179.000000   3.000000   3500.000000
# 25%     35836.250000   4.000000   4625.000000
# 50%     57369.000000   4.000000   6625.000000
# 75%     96384.500000   4.000000   7375.000000
# max    213095.000000   5.000000  22000.000000

# %% [markdown]
# * regular _ regex _provide a flexible way to search or match with patterns in text

# %%
import re

# %%
 text = 'foo bar\t baz \tquz'

# %%
re.split('\s+', text)   #\s+ is regex for one or more whitespace
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\3717659578.py:1: SyntaxWarning: invalid escape sequence '\s'
#   re.split('\s+', text)   #\s+ is regex for one or more whitespace
# ['foo', 'bar', 'baz', 'quz']

# %%
regex = re.compile('\s+')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ephan\AppData\Local\Temp\ipykernel_21568\1890572334.py:1: SyntaxWarning: invalid escape sequence '\s'
#   regex = re.compile('\s+')

# %%
regex.split(text)
# Out:
# ['foo', 'bar', 'baz', 'quz']

# %%
regex.findall(text)
# Out:
# [' ', '\t ', ' \t']

# %% [markdown]
# # 20^th SEP 2025

# %% [markdown]
# > Data wrangling - combining and merging

# %%
# Hierarchical indexing - allows to work with hugher dimensions in a lower dimension form
series_2idx = pd.Series(np.random.randn(9),
                        index=[['a', 'a', 'a', 'b', 'b', 'c', 'c',  'd', 'd'],
                               [1,2,3,1,3,1,2,2,3]])
series_2idx
# Out:
# a  1    0.997734
#    2   -1.179614
#    3    0.239110
# b  1   -0.849904
#    3   -0.501348
# c  1   -0.782265
#    2    0.731013
# d  2    0.211247
#    3   -0.841909
# dtype: float64

# %%
series_2idx.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 3),
#             ('c', 1),
#             ('c', 2),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
series_2idx['a']  #Outer index
# Out:
# 1    0.997734
# 2   -1.179614
# 3    0.239110
# dtype: float64

# %%
series_2idx.loc[:,2] #inner index
# Out:
# a   -1.179614
# c    0.731013
# d    0.211247
# dtype: float64

# %%
# Transform to DataFrame - pivot
series_2idx.unstack()
# Out:
#           1         2         3
# a  0.997734 -1.179614  0.239110
# b -0.849904       NaN -0.501348
# c -0.782265  0.731013       NaN
# d       NaN  0.211247 -0.841909

# %%
# pd.merge - connects DataFrames based on one or more keys  similar to joins in SQL
df1 = pd.DataFrame({'key':['b', 'b', 'a', 'c', 'a', 'a', 'b'], 
                    'data1':range(7)})
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2 = pd.DataFrame({'key': ['a', 'b', 'd'], 'data2': range(3)})
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.merge(df1, df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   a      2      0
# 3   a      4      0
# 4   a      5      0
# 5   b      6      1

# %%
pd.merge(df1, df2, on='key')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   a      2      0
# 3   a      4      0
# 4   a      5      0
# 5   b      6      1

# %%
pd.merge(df1, df2, how ='outer')
# Out:
#   key  data1  data2
# 0   a    2.0    0.0
# 1   a    4.0    0.0
# 2   a    5.0    0.0
# 3   b    0.0    1.0
# 4   b    1.0    1.0
# 5   b    6.0    1.0
# 6   c    3.0    NaN
# 7   d    NaN    2.0

# %%
pd.merge(df1, df2, how='right')
# Out:
#   key  data1  data2
# 0   a    2.0      0
# 1   a    4.0      0
# 2   a    5.0      0
# 3   b    0.0      1
# 4   b    1.0      1
# 5   b    6.0      1
# 6   d    NaN      2

# %%
pd.merge(df1, df2, how='left')
# Out:
#   key  data1  data2
# 0   b      0    1.0
# 1   b      1    1.0
# 2   a      2    0.0
# 3   c      3    NaN
# 4   a      4    0.0
# 5   a      5    0.0
# 6   b      6    1.0

# %%
# pd.concat()
s1 = pd.Series([0,1], index=['a', 'b'])
s2 = pd.Series([2,3,4], index=['c', 'd', 'e'])
s3 = pd.Series([5,6], index = ['f', 'g'])

# %%
s1, s2, s3
# Out:
# (a    0
#  b    1
#  dtype: int64,
#  c    2
#  d    3
#  e    4
#  dtype: int64,
#  f    5
#  g    6
#  dtype: int64)

# %%
s1
# Out:
# a    0
# b    1
# dtype: int64

# %%
s2
# Out:
# c    2
# d    3
# e    4
# dtype: int64

# %%
s3
# Out:
# f    5
# g    6
# dtype: int64

# %%
# concat list
pd.concat([s1, s2, s3], axis = 0)
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1,s2,s3], axis = 1)
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
# Concat -df
pd.concat([df1, df2])
# Out:
#   key  data1  data2
# 0   b    0.0    NaN
# 1   b    1.0    NaN
# 2   a    2.0    NaN
# 3   c    3.0    NaN
# 4   a    4.0    NaN
# 5   a    5.0    NaN
# 6   b    6.0    NaN
# 0   a    NaN    0.0
# 1   b    NaN    1.0
# 2   d    NaN    2.0

# %%
pd.concat([df1, df2], axis=1)
# Out:
#   key  data1  key  data2
# 0   b      0    a    0.0
# 1   b      1    b    1.0
# 2   a      2    d    2.0
# 3   c      3  NaN    NaN
# 4   a      4  NaN    NaN
# 5   a      5  NaN    NaN
# 6   b      6  NaN    NaN

# %% [markdown]
#  **Home study** -df.melt

# %%
df.melt()
# Out:
#     variable     value
# 0          0 -1.392559
# 1          0  1.686418
# 2          0 -1.822184
# 3          0 -0.117215
# 4          0  0.246934
# 5          0  0.245673
# 6          1 -0.029686
# 7          1  0.618994
# 8          1       NaN
# 9          1       NaN
# 10         1       NaN
# 11         1  0.122903
# 12         2  1.116577
# 13         2  0.604537
# 14         2  2.262824
# 15         2 -0.613925
# 16         2       NaN
# 17         2       NaN
# 18         3  3.116577
# 19         3  2.604537
# 20         3  4.262824
# 21         3  1.386075
# 22         3       NaN
# 23         3       NaN

# %% [markdown]
# ***Plotting and Visualization with Pandas***

# %% [markdown]
# *Line Plots*

# %% [markdown]
# > Series and DataFrame each have a plot method for making some basic plot types

# %%
series_data = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0,100, 10))
series_data
# Out:
# 0     0.133013
# 10   -1.292961
# 20   -0.412987
# 30   -1.245730
# 40   -0.270855
# 50   -0.275428
# 60   -0.388053
# 70   -1.147432
# 80    0.373894
# 90   -2.110096
# dtype: float64

# %%
series_data.plot()
# Out:
# <Axes: >

# %%
series_data.plot();

# %%
df = pd.DataFrame(np.random.uniform(low=0, high=10, size=(10, 4),
                  columns=['A', 'B', 'C', 'D'],
                  index = np.arange(0, 100, 10)))
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[329], line 1
# ----> 1 df = pd.DataFrame(np.random.uniform(low=0, high=10, size=(10, 4),
#       2                   columns=['A', 'B', 'C', 'D'],
#       3                   index = np.arange(0, 100, 10)))
#       4 df.head(2)
#
# File numpy\\random\\mtrand.pyx:1050, in numpy.random.mtrand.RandomState.uniform()
#
# TypeError: uniform() got an unexpected keyword argument 'columns'

# %%
df.plot();

# %% [markdown]
# # Bar Plots

# %% [markdown]
# `plot.bar()` and `plot.barh`

# %%
data = pd.Series(np.random.rand(16), index = list('abcdefghijklmnop'))
data
# Out:
# a    0.945143
# b    0.624022
# c    0.266626
# d    0.903183
# e    0.265877
# f    0.325962
# g    0.015539
# h    0.223908
# i    0.239988
# j    0.986853
# k    0.495247
# l    0.352125
# m    0.505477
# n    0.114564
# o    0.528762
# p    0.404069
# dtype: float64

# %%
data.plot.bar();

# %%
data.plot(kind='bar', title = 'A Bar Chart', color ='r');

# %%
data.plot(kind='bar', title = 'A Bar Chart', color ='tab:purple', alpha=0.1);

# %%
data.plot(kind='barh',color='green', alpha=0.4, edgecolor='red', linewidth=9);

# %%
df
# Out:
#           0         1         2         3
# 0 -1.392559 -0.029686  1.116577  3.116577
# 1  1.686418  0.618994  0.604537  2.604537
# 2 -1.822184       NaN  2.262824  4.262824
# 3 -0.117215       NaN -0.613925  1.386075
# 4  0.246934       NaN       NaN       NaN
# 5  0.245673  0.122903       NaN       NaN

# %%
# plot with DataFrame
df.plot.bar();

# %%
# plot as a stacked bar
df.plot.bar(title='Stacked bar chart', stacked=True);

# %%
# Plot with real data
uk_accidents['Accident_Severity'].value_counts().plot.bar();

# %%
party_count = pd.crosstab(tips['day'], tips['size'])
party_count
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_count.plot.bar();

# %%
party_count.plot.bar(stacked=True);

# %%
tips['tip'].plot.hist(bin);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[342], line 1
# ----> 1 tips['tip'].plot.hist(bin)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1409, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1349 def hist(
#    1350     self, by: IndexLabel | None = None, bins: int = 10, **kwargs
#    1351 ) -> PlotAccessor:
#    1352     """
#    1353     Draw one histogram of the DataFrame's columns.
#    1354
#    (...)
#    1407         >>> ax = df.plot.hist(column=["age"], by="gender", figsize=(10, 8))
#    1408     """
# -> 1409     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# ...

# %%
tips['tip'].plot(kind='hist',bins=20);

# %%
tips['tip'].plot.density();

# %% [markdown]
# # Scatter Plot- Point Plot

# %% [markdown]
# > This helps to examine the relationship between two ome dimensional data series

# %%
tips

# %%
tips.plot(kind='scatter', x='total_bill', y='tip');
